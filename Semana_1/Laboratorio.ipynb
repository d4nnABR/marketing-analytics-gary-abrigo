# %% [markdown]
# <a href="https://colab.research.google.com/github/d4nnABR/marketing-analytics-gary-abrigo/blob/main/Semana_1/Laboratorio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# # 1. Trae tu repositorio a Colab
# ```

# %%
# !git clone https://github.com/d4nnABR/marketing-analytics-gary-abrigo

# %%
# %cd marketing-analytics-gary-abrigo/Semana_1
# Out:
# /content/marketing-analytics-gary-abrigo/Semana_1

# %%
# !pip install -r ../requirements.txt
# Out:
# ...
#   Using cached causalml-0.17.0.tar.gz (1.9 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached pycaret-3.3.2-py3-none-any.whl.metadata (17 kB)
# ...
#   Using cached streamlit-1.64.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached forestci-0.6-py3-none-any.whl.metadata (1.3 kB)
# ...
#   Using cached pathos-0.2.9-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached black-26.5.1-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (95 kB)
# ...
#   Using cached ppft-1.7.8-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached pox-0.3.7-py3-none-any.whl.metadata (8.0 kB)
# ...
#   Using cached numpy-1.26.4.tar.gz (15.8 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done

# %%
from sklearn.linear_model import LinearRegression
import numpy as np
variable_x = np.array([[10], [20], [30], [40],[50]])
variable_y = np.array([15,25,35,45,55])
modelo_lr = LinearRegression()
modelo_lr.fit(variable_x,variable_y)
gasto = 100
resultado = modelo_lr.predict([[gasto]])
print(f"Las ventas proyectadas para una inversión de ${gasto} son: ${resultado[0]}")
# Out:
# Las ventas proyectadas para una inversión de $100 son: $105.0
